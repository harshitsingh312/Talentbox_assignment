# %%
import pandas as pd

# %%
df = pd.read_csv("D:\kepler_data.csv")

# %%
df
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# 5     10872983  K00756.01  Kepler-228 d       CONFIRMED        CANDIDATE
# 6     10872983  K00756.02  Kepler-228 c       CONFIRMED        CANDIDATE
# 7     10872983  K00756.03  Kepler-228 b       CONFIRMED        CANDIDATE
# 8      6721123  K00114.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9     10910878  K00757.01  Kepler-229 c       CONFIRMED        CANDIDATE
# 10    11446443  K00001.01    Kepler-1 b       CONFIRMED        CANDIDATE
# 11    10666592  K00002.01    Kepler-2 b       CONFIRMED        CANDIDATE
# ...

# %%
df1 = df

# %%
df1
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# 5     10872983  K00756.01  Kepler-228 d       CONFIRMED        CANDIDATE
# 6     10872983  K00756.02  Kepler-228 c       CONFIRMED        CANDIDATE
# 7     10872983  K00756.03  Kepler-228 b       CONFIRMED        CANDIDATE
# 8      6721123  K00114.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9     10910878  K00757.01  Kepler-229 c       CONFIRMED        CANDIDATE
# 10    11446443  K00001.01    Kepler-1 b       CONFIRMED        CANDIDATE
# 11    10666592  K00002.01    Kepler-2 b       CONFIRMED        CANDIDATE
# ...

# %% [markdown]
# Preprocessing: removal of features with string or null values

# %%
df1 = df1.drop(['kepid','kepoi_name','kepler_name','koi_pdisposition'],axis=1)

# %%
df1 = df1.drop(['koi_teq_err1','koi_teq_err2','koi_tce_delivname'],axis=1)

# %%
df1.shape
# Out:
# (9564, 42)

# %%
df1 = df1.dropna()

# %%
df1.shape
# Out:
# (7803, 42)

# %%
Y=df1['koi_disposition']

# %%
X = df1.drop(['koi_disposition'],axis=1)

# %%
X.shape
# Out:
# (7803, 41)

# %%
Y.shape
# Out:
# (7803,)

# %%
#training and testing dataset split into 75% & 25%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)

# %%
#Standardization and Normalization of dataset
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Implementation of multiclass Support Vector Machine

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear')

# %%
clf.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
Y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(Y_test, Y_pred)
print(cm)
accuracy_score(Y_test,Y_pred)
# Out:
# [[300 151   1]
#  [ 83 503   1]
#  [  2   0 910]]
# 0.8780112762685802

# %% [markdown]
# Implementation of Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state=0)
model.fit(X_train,Y_train)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
Y_pred2 = model.predict(X_test)

# %%
cm2 = confusion_matrix(Y_test, Y_pred2)
print(cm2)
accuracy_score(Y_test,Y_pred2)
# Out:
# [[329 112  11]
#  [106 479   2]
#  [  0   0 912]]
# 0.8815991799077396

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, Y_train)
# Out:
# GaussianNB(priors=None)

# %%
Y_pred3 = classifier.predict(X_test)

# %%
cm3 = confusion_matrix(Y_test, Y_pred3)
print(cm3)
accuracy_score(Y_test,Y_pred3)
# Out:
# [[120 322  10]
#  [ 44 541   2]
#  [  0  30 882]]
# 0.7908764736032804
